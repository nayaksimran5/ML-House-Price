# %% [markdown]
# ## Project Description

# %% [markdown]
# The House Price Prediction System is a comprehensive machine learning project designed to predict the sale prices of residential properties based on various features. This project aims to leverage historical data to build a predictive model that can assist buyers, sellers, and real estate professionals in making informed decisions regarding property transactions.

# %% [markdown]
# ## Objectives

# %% [markdown]
# - **Data Analysis**: To explore and analyze the dataset, identifying key features that influence house prices.
# - **Data Preprocessing**: To clean and preprocess the data, handling missing values, encoding categorical variables, and normalizing numerical features.
# - **Model Development**: To implement and compare various machine learning algorithms, including linear regression, decision trees, random forests, and gradient boosting methods.
# - **Model Evaluation**: To evaluate the performance of different models using metrics such as Mean Absolute Error (MAE), Mean Squared Error (MSE), and R-squared values.
# - **Model Optimization**: To fine-tune the selected model using techniques like cross-validation and hyperparameter tuning for improved accuracy.

# %% [markdown]
# ### Data Sources

# %% [markdown]
# The dataset used for this project is derived from the [House Prices - Advanced Regression Techniques](https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/overview) competition on Kaggle.

# %% [markdown]
# # Data Fields
# Here's a brief data description file.
#
# **SalePrice**: the property's sale price in dollars. This is the target variable that you're trying to predict.
#
# **MSSubClass**: The building class
#
# **MSZoning**: The general zoning classification
#
# **LotFrontage**: Linear feet of street connected to property
#
# **LotArea**: Lot size in square feet
#
# **Street**: Type of road access
#
# **Alley**: Type of alley access
#
# **LotShape**: General shape of property
#
# **LandContour**: Flatness of the property
#
# **Utilities**: Type of utilities available
#
# **LotConfig**: Lot configuration
#
# **LandSlope**: Slope of property
#
# **Neighborhood**: Physical locations within Ames city limits
#
# **Condition1**: Proximity to main road or railroad
#
# **Condition2**: Proximity to main road or railroad (if a second is present)
#
# **BldgType**: Type of dwelling
#
# **HouseStyle**: Style of dwelling
#
# **OverallQual**: Overall material and finish quality
#
# **OverallCond**: Overall condition rating
#
# **YearBuilt**: Original construction date
#
# **YearRemodAdd**: Remodel date
#
# **RoofStyle**: Type of roof
#
# **RoofMatl**: Roof material
#
# **Exterior1st**: Exterior covering on house
#
# **Exterior2nd**: Exterior covering on house (if more than one material)
#
# **MasVnrType**: Masonry veneer type
#
# **MasVnrArea**: Masonry veneer area in square feet
#
# **ExterQual**: Exterior material quality
#
# **ExterCond**: Present condition of the material on the exterior
#
# **Foundation**: Type of foundation
#
# **BsmtQual**: Height of the basement
#
# **BsmtCond**: General condition of the basement
#
# **BsmtExposure**: Walkout or garden level basement walls
#
# **BsmtFinType1**: Quality of basement finished area
#
# **BsmtFinSF1**: Type 1 finished square feet
#
# **BsmtFinType2**: Quality of second finished area (if present)
#
# **BsmtFinSF2**: Type 2 finished square feet
#
# **BsmtUnfSF**: Unfinished square feet of basement area
#
# **TotalBsmtSF**: Total square feet of basement area
#
# **Heating**: Type of heating
#
# **HeatingQC**: Heating quality and condition
#
# **CentralAir**: Central air conditioning
#
# **Electrical**: Electrical system
#
# **1stFlrSF**: First Floor square feet
#
# **2ndFlrSF**: Second floor square feet
#
# **LowQualFinSF**: Low quality finished square feet (all floors)
#
# **GrLivArea**: Above grade (ground) living area square feet
#
# **BsmtFullBath**: Basement full bathrooms
#
# **BsmtHalfBath**: Basement half bathrooms
#
# **FullBath**: Full bathrooms above grade
#
# **HalfBath**: Half baths above grade
#
# **Bedroom**: Number of bedrooms above basement level
#
# **Kitchen**: Number of kitchens
#
# **KitchenQual**: Kitchen quality
#
# **TotRmsAbvGrd**: Total rooms above grade (does not include bathrooms)
#
# **Functional**: Home functionality rating
#
# **Fireplaces**: Number of fireplaces
#
# **FireplaceQu**: Fireplace quality
#
# **GarageType**: Garage location
#
# **GarageYrBlt**: Year garage was built
#
# **GarageFinish**: Interior finish of the garage
#
# **GarageCars**: Size of garage in car capacity
#
# **GarageArea**: Size of garage in square feet
#
# **GarageQual**: Garage quality
#
# **GarageCond**: Garage condition
#
# **PavedDrive**: Paved driveway
#
# **WoodDeckSF**: Wood deck area in square feet
#
# **OpenPorchSF**: Open porch area in square feet
#
# **EnclosedPorch**: Enclosed porch area in square feet
#
# **3SsnPorch**: Three season porch area in square feet
#
# **ScreenPorch**: Screen porch area in square feet
#
# **PoolArea**: Pool area in square feet
#
# **PoolQC**: Pool quality
#
# **Fence**: Fence quality
#
# **MiscFeature**: Miscellaneous feature not covered in other categories
#
# **MiscVal**: $Value of miscellaneous feature
#
# **MoSold**: Month Sold
#
# **YrSold**: Year Sold
#
# **SaleType**: Type of sale
#
# **SaleCondition**: Condition of sale

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading the datasets

# %%
# Read the data
train_df = pd.read_csv('/Users/simrannayak/Desktop/Build Project ML Data/Dataset/train (1).csv')
test_df = pd.read_csv('/Users/simrannayak/Desktop/Build Project ML Data/Dataset/test (1).csv')

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
train_df.shape
# Out:
# (1460, 81)

# %%
test_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
test_df.shape
# Out:
# (1459, 80)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train_df.describe().T
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# ...

# %%
# with pd.option_context('display.max_rows', None): print(train_df.dtypes)

# Types of Data
list(set(train_df.dtypes.tolist()))
# Out:
# [dtype('O'), dtype('float64'), dtype('int64')]

# %%
#Display all the unique containt in each column

for col in train_df.describe(include=['int64','float64', 'object']).columns:
    print(col)
    print(train_df[col].value_counts())
    print('-'*50)
# Out:
# Id
# 1       1
# 982     1
# 980     1
# 979     1
# 978     1
#        ..
# 485     1
# 484     1
# 483     1
# 482     1
# 1460    1
# Name: Id, Length: 1460, dtype: int64
# --------------------------------------------------
# MSSubClass
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: MSSubClass, dtype: int64
# --------------------------------------------------
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64
# --------------------------------------------------
# LotFrontage
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
#         ...
# 137.0      1
# 141.0      1
# 38.0       1
# 140.0      1
# 46.0       1
# Name: LotFrontage, Length: 110, dtype: int64
# --------------------------------------------------
# LotArea
# ...

# %% [markdown]
# ### Data Visualization

# %%
# Correlation Matrix
corr_matrix = train_df.select_dtypes(include=['number']).corr().style.background_gradient(cmap='coolwarm')
corr_matrix
# Out:
# <style type="text/css">
# #T_db53a_row0_col0, #T_db53a_row1_col1, #T_db53a_row2_col2, #T_db53a_row3_col3, #T_db53a_row4_col4, #T_db53a_row5_col5, #T_db53a_row6_col6, #T_db53a_row7_col7, #T_db53a_row8_col8, #T_db53a_row9_col9, #T_db53a_row10_col10, #T_db53a_row11_col11, #T_db53a_row12_col12, #T_db53a_row13_col13, #T_db53a_row14_col14, #T_db53a_row15_col15, #T_db53a_row16_col16, #T_db53a_row17_col17, #T_db53a_row18_col18, #T_db53a_row19_col19, #T_db53a_row20_col20, #T_db53a_row21_col21, #T_db53a_row22_col22, #T_db53a_row23_col23, #T_db53a_row24_col24, #T_db53a_row25_col25, #T_db53a_row26_col26, #T_db53a_row27_col27, #T_db53a_row28_col28, #T_db53a_row29_col29, #T_db53a_row30_col30, #T_db53a_row31_col31, #T_db53a_row32_col32, #T_db53a_row33_col33, #T_db53a_row34_col34, #T_db53a_row35_col35, #T_db53a_row36_col36, #T_db53a_row37_col37 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# ...

# %%
# Top 10 highest correlations with SalePrice
corrmat = train_df.corr() # Calculate the correlation matrix
k = 10 # number of variables for heatmap
cols = corrmat.nlargest(k, 'SalePrice')['SalePrice'].index
cm = np.corrcoef(train_df[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %% [markdown]
# According to the above plot, these are the variables most correlated with **'SalePrice'**.
#
# - **'OverallQual', 'GrLivArea'** and **'TotalBsmtSF'** are strongly correlated with **'SalePrice'**.
#
# - Both **'GarageCars'** and **'GarageArea'** are among the variables most strongly correlated with eachother. However, the number of cars that can fit into the garage is dependent on the garage area, making these two variables highly collinear. Given this collinearity, we should include only one of these variables in our analysis to avoid redundancy. We will retain **'GarageCars'** because it has a higher correlation with **'SalePrice'**.
#
# - Similarly, **'TotalBsmtSF'** and **'1stFloor'** show a strong correlation with each other. To maintain the integrity of our analysis and avoid redundancy, we will retain **'TotalBsmtSF'**. This decision is based on the logical reasoning that **'TotalBsmtSF'** has a significant impact on house price data, making it a critical variable to include in our model.
#
# - Similarly, **'TotRmsAbvGrd'** and **'GrLivArea'**, show a strong correlation with each other.
#
# - It seems that **'YearBuilt'** is slightly correlated with **'SalePrice'**.

# %%
# Select numerical columns
numerical_vars = train_df.select_dtypes(include=['int64','float64'])

# Select categorical columns
categorical_vars = train_df.select_dtypes(include=['object'])

# %% [markdown]
# Now let's plot the histogram distribution for all the numerical features

# %%
# Distribution of numerical features
numerical_vars.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8);

# %% [markdown]
# ### Missing Values

# %%
with pd.option_context('display.max_rows', None):
     print(train_df.isna().sum().T.sort_values(ascending=False))
# Out:
# PoolQC           1453
# MiscFeature      1406
# Alley            1369
# Fence            1179
# FireplaceQu       690
# LotFrontage       259
# GarageYrBlt        81
# GarageCond         81
# GarageType         81
# GarageFinish       81
# GarageQual         81
# BsmtFinType2       38
# BsmtExposure       38
# BsmtQual           37
# BsmtCond           37
# BsmtFinType1       37
# MasVnrArea          8
# MasVnrType          8
# Electrical          1
# Id                  0
# Functional          0
# Fireplaces          0
# KitchenQual         0
# KitchenAbvGr        0
# BedroomAbvGr        0
# HalfBath            0
# FullBath            0
# BsmtHalfBath        0
# TotRmsAbvGrd        0
# GarageCars          0
# GrLivArea           0
# GarageArea          0
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# PoolArea            0
# MiscVal             0
# MoSold              0
# ...

# %%
# Missing values percentage
total = train_df.isnull().sum().sort_values(ascending=False)
percent = (train_df.isnull().sum()/train_df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#               Total   Percent
# PoolQC         1453  0.995205
# MiscFeature    1406  0.963014
# Alley          1369  0.937671
# Fence          1179  0.807534
# FireplaceQu     690  0.472603
# LotFrontage     259  0.177397
# GarageYrBlt      81  0.055479
# GarageCond       81  0.055479
# GarageType       81  0.055479
# GarageFinish     81  0.055479
# GarageQual       81  0.055479
# BsmtFinType2     38  0.026027
# BsmtExposure     38  0.026027
# BsmtQual         37  0.025342
# BsmtCond         37  0.025342
# BsmtFinType1     37  0.025342
# MasVnrArea        8  0.005479
# MasVnrType        8  0.005479
# Electrical        1  0.000685
# Id                0  0.000000

# %% [markdown]
# #### Dropping Columns with High Missing Values:
#
# From the above plot, we can observe that the **'PoolQC', 'MiscFeature', 'Alley'** and **'Fence'** columns have more than 80% of their data missing. As these columns lack valuable information and have a significant amount of missing data, it is prudent to drop them from the original dataset. This will make the dataset simpler and help improve the accuracy of our house price predictions.

# %%
train_df = train_df.drop(columns=['PoolQC', 'MiscFeature', 'Alley','Fence'], axis = 1)

# %%
test_df = test_df.drop(columns=['PoolQC', 'MiscFeature', 'Alley','Fence'], axis = 1)

# %% [markdown]
# ### Handling Missing values

# %% [markdown]
# #### Fireplace Variable

# %%
train_df['FireplaceQu'].fillna('None', inplace=True)

# %% [markdown]
# ### Duplicate Values

# %%
with pd.option_context('display.max_rows', None):
     print(train_df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# There are no duplicate values in the dataset.

# %%
# Out:
# Id
# 1       1
# 982     1
# 980     1
# 979     1
# 978     1
#        ..
# 485     1
# 484     1
# 483     1
# 482     1
# 1460    1
# Name: Id, Length: 1460, dtype: int64
# --------------------------------------------------
# MSSubClass
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: MSSubClass, dtype: int64
# --------------------------------------------------
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64
# --------------------------------------------------
# LotFrontage
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
#         ...
# 137.0      1
# 141.0      1
# 38.0       1
# 140.0      1
# 46.0       1
# Name: LotFrontage, Length: 110, dtype: int64
# --------------------------------------------------
# LotArea
# ...

# %%
# Understanding Categorical Column
def categorical_summary(dataframe, col_name):

    print(pd.DataFrame({

        col_name: dataframe[col_name].value_counts(),  # Count of unique values

        "Ratio": 100 * dataframe[col_name].value_counts() / len(dataframe)  # Percentage of each unique value

    }))

    print("------------------------------------------------------------------")

# %%
# Categorical Summary in Training set
for col in categorical_vars:

    categorical_summary(train_df, col)
# Out:
#          MSZoning      Ratio
# RL           1151  78.835616
# RM            218  14.931507
# FV             65   4.452055
# RH             16   1.095890
# C (all)        10   0.684932
# ------------------------------------------------------------------
#       Street      Ratio
# Pave    1454  99.589041
# Grvl       6   0.410959
# ------------------------------------------------------------------
#       Alley     Ratio
# Grvl     50  3.424658
# Pave     41  2.808219
# ------------------------------------------------------------------
#      LotShape      Ratio
# Reg       925  63.356164
# IR1       484  33.150685
# IR2        41   2.808219
# IR3        10   0.684932
# ------------------------------------------------------------------
#      LandContour      Ratio
# Lvl         1311  89.794521
# Bnk           63   4.315068
# HLS           50   3.424658
# Low           36   2.465753
# ------------------------------------------------------------------
#         Utilities      Ratio
# ...

# %% [markdown]
# #### Dropping Categorical Columns with Imbalanced Distribution:
#
# I removed categorical columns with highly imbalanced distributions. These columns are dominated by a single category, making them less useful for the model and potentially introducing noise. Specifically, I removed **'Condition2', 'RoofMatl', 'Utilities', 'Street'** and **'Heating'** from both the training and test sets. This step aims to enhance data quality and improve model performance.

# %%
# Droping from training dataset
train_df.drop(["Condition2","RoofMatl","Utilities","Street","Heating"], axis=1, inplace= True)

# %%
# Droping from test dataset
test_df.drop(["Condition2","RoofMatl","Utilities","Street","Heating"], axis=1, inplace= True)

# %%
# Understanding Numerical Column
def numerical_summary(dataframe, col_name):

    print(pd.DataFrame({

        col_name: dataframe[col_name].value_counts(),  # Count of unique values

        "Ratio": 100 * dataframe[col_name].value_counts() / len(dataframe)  # Percentage of each unique value

    }))

    print("------------------------------------------------------------------")

# %%
# Numerical Summary in Training set
for col in numerical_vars:

    numerical_summary(train_df, col)
# Out:
#       Id     Ratio
# 1      1  0.068493
# 982    1  0.068493
# 980    1  0.068493
# 979    1  0.068493
# 978    1  0.068493
# ...   ..       ...
# 485    1  0.068493
# 484    1  0.068493
# 483    1  0.068493
# 482    1  0.068493
# 1460   1  0.068493
#
# [1460 rows x 2 columns]
# ------------------------------------------------------------------
#      MSSubClass      Ratio
# 20          536  36.712329
# 60          299  20.479452
# 50          144   9.863014
# 120          87   5.958904
# 30           69   4.726027
# 160          63   4.315068
# 70           60   4.109589
# 80           58   3.972603
# 90           52   3.561644
# 190          30   2.054795
# 85           20   1.369863
# 75           16   1.095890
# 45           12   0.821918
# 180          10   0.684932
# 40            4   0.273973
# ------------------------------------------------------------------
#        LotFrontage     Ratio
# 60.0           143  9.794521
# 70.0            70  4.794521
# ...

# %%
# Exploring the target variable
train_df['SalePrice'].hist()
# Out:
# <AxesSubplot:>

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(14, 6))

# Histogram Of SalesPrice
plt.subplot(1, 2, 1)
sns.histplot(train_df["SalePrice"], bins=30, color="#89CFF0", kde=True)
plt.title("Histogram of SalePrice")
plt.xlabel("SalePrice")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# From the above, we can see that **SalePrice** is right-skewed.
#
# **Problem**
#
# Skewed data can negatively impact the performance of models, particularly linear regression models, by increasing prediction errors. This is because skewed distributions can lead to non-representative statistics like the mean and variance, which makes it harder for the model to learn effectively and make accurate predictions.
#
# **Solution**
#
# To address these issues, you can consider transforming the target variable, such as using a log transformation or square root transformation, to reduce skewness. This can improve model performance.

# %% [markdown]
# ### Log Transformation

# %%
# Log Transformation
train_df["LogSalePrice"] = np.log1p(train_df["SalePrice"])
print(f"The skewness decrease from {round(train_df['SalePrice'].skew(), 2)} to {round(train_df['SalePrice_Log'].skew(), 2)}.")
# Out:
# The skewness decrease from 1.88 to 0.12.

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(14, 6))

# Histogram Of LogSalesPrice
plt.subplot(1, 2, 1)
sns.histplot(train_df["LogSalePrice"], bins=30, color="#89CFF0", kde=True)
plt.title("Histogram of LogSalePrice")
plt.xlabel("LogSalePrice")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')
